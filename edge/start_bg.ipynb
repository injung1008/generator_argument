# %%
import background_remove as br
# Out:
# OMP: Info #276: omp_set_nested routine deprecated, please use omp_set_max_active_levels instead.

# %%
back_img_path = '/data/ij/coco_img/val2017'
target_img_path = '/data/ij/background_remove/target_mask'
result_path = '/data/ij/background_remove/coco_datset'
br.main(back_img_path,target_img_path,result_path)
# Out:
# category_id : 0, category_name : syringe
# 0.jpg
# resize_size : 1.35
# resize_size : 1.7999999999999998
# resize_size : 1.35
# 1.jpg
# resize_size : 1.6500000000000001
# resize_size : 1.6500000000000001
# 2.jpg
# resize_size : 1.5
# resize_size : 1.6500000000000001
# 3.jpg
# resize_size : 1.5
# resize_size : 1.6500000000000001
# 4.jpg
# resize_size : 1.5
# 5.jpg
# 6.jpg
# resize_size : 1.5
# 7.jpg
# resize_size : 1.5
# resize_size : 1.5
# resize_size : 1.5
# 8.jpg
# resize_size : 1.6500000000000001
# 9.jpg
# resize_size : 1.7999999999999998
# resize_size : 1.6500000000000001
# resize_size : 2.25
# 10.jpg
# resize_size : 1.5
# resize_size : 1.5
# 11.jpg
# resize_size : 2.0999999999999996
# resize_size : 1.6500000000000001
# resize_size : 1.9500000000000002
# 12.jpg
# resize_size : 1.9500000000000002
# 13.jpg
# resize_size : 1.5
# resize_size : 1.9500000000000002
# 14.jpg
# resize_size : 1.6500000000000001
# resize_size : 1.7999999999999998
# 15.jpg
# resize_size : 1.6500000000000001
# ...
